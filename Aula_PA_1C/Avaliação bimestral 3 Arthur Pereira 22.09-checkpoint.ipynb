# %% [markdown]
# Nome: Arthur Pereira de Almeida Campos

# %% [markdown]
# **Atividade Avaliativa **
#
# Enunciado:
#
# Crie um programa em Python para avaliar uma competição de bandas de música. O programa deve:
#
# Perguntar a quantidade de bandas participantes (mínimo 3).
#
# Perguntar o nome de cada banda.
#
# Para cada banda, receber as notas de 5 jurados (valores de 0 a 10).
#
# Calcular a média das notas de cada banda e armazenar o resultado em um dicionário, onde a chave será o nome da banda e o valor será a média das notas.
#
# Ao final, mostrar:
#
# A média de cada banda.
#
# O nome da banda vencedora (a que tiver maior média).

# %%
# Digite sua resposta

while True:
    try:
        qtd = int(input("Quantas bandas vão participar? (Mínimo de 3)"))
        if qtd >= 3:
            break
        else:
            print("O mínimo de bandas é 3")
    except ValueError:
        print("Digite um número inteiro válido.")
        
bandas = {}

for i in range(qtd):
    nome = input(f"Digite o nome da banda {i+1}: ")
    
    notas = []
    for j in range(5):
        while True:
            try:
                nota = float(input(f"Nota do jurado {j+1} para {nome}: "))
                if 0 <= nota <= 10:
                    notas.append(nota)
                    break
                else:
                    print("Nota inválida. Digite uma nota entre 0 e 10.")
            except ValueError:
                print("Digite um número válido.")
        media = sum(notas) / len(notas)
        bandas[nome] = media
        
print("Média das bandas:")
for nome, media in bandas.items():
        print(f"{nome}: {media:.2f}")
        
vencedora = max(bandas, key=bandas.get)
print(f"A banda vencedora é: {vencedora} com {media} pontos!")
# Out:
# Quantas bandas vão participar? (Mínimo de 3)2
# O mínimo de bandas é 3
# Quantas bandas vão participar? (Mínimo de 3)3
# Digite o nome da banda 1: Popstar
# Nota do jurado 1 para Popstar: 7.5
# Nota do jurado 2 para Popstar: 8
# Nota do jurado 3 para Popstar: 7
# Nota do jurado 4 para Popstar: 8
# Nota do jurado 5 para Popstar: 6.5
# Digite o nome da banda 2: Rockstar
# Nota do jurado 1 para Rockstar: 8
# Nota do jurado 2 para Rockstar: 6.5
# Nota do jurado 3 para Rockstar: 4.5
# Nota do jurado 4 para Rockstar: 7
# Nota do jurado 5 para Rockstar: 7.5
# Digite o nome da banda 3: Classics
# Nota do jurado 1 para Classics: 8
# Nota do jurado 2 para Classics: 9
# Nota do jurado 3 para Classics: 9.5
# Nota do jurado 4 para Classics: 7.5
# Nota do jurado 5 para Classics: 8.5
# Média das bandas:
# Popstar: 7.40
# Rockstar: 6.70
# Classics: 8.50
# A banda vencedora é: Classics com 8.5 pontos!

# %% [markdown]
# Enunciado:
#
# Crie um programa que conte quantas vezes cada palavra aparece em uma frase.
#
# Pedir ao usuário para digitar uma frase
#
# Imprimir a palavra e quantas vezes ela aparece

# %%
# Digite sua resposta

frase = input("Digite uma frase: ")
palavras = frase.split ()

contagem = {}

for p in palavras:
    p = p.lower()
    contagem [p] = contagem.get(p, 0) + 1
    
for palavra, qtd in contagem.items ():
    print(f"{palavra}: {qtd}")
# Out:
# Digite uma frase: Olá, gostaria de uma xícara de chá, e de um copo com água, e de um biscoito maizena.
# olá,: 1
# gostaria: 1
# de: 4
# uma: 1
# xícara: 1
# chá,: 1
# e: 2
# um: 2
# copo: 1
# com: 1
# água,: 1
# biscoito: 1
# maizena.: 1

# %% [markdown]
# Enunciado:
#
# Crie um programa em python que imprima números pares
#
# Pedir o usuário para digitar uma lista com mínimo 10 números
#
# Criar uma nova somente com numeros pares
#
# Imprimir números pares

# %%
# Digite sua resposta

numeros = []
while len(numeros) < 10:
    entrada = input("Digite uma lista com pelo menos 10 números separados por espaço: ")
    try:
        lista = [int(x) for x in entrada.split()]
        numeros.extend(lista)
    except ValueError:
        print("Digite apenas números inteiros.")
        
pares = [n for n in numeros if n % 2 == 0]
print("Lista original: ", numeros)
print("Números pares: ", pares )
# Out:
# Digite uma lista com pelo menos 10 números separados por espaço: 10 85 74 6 5 15 122 35 98 48 564 165 154
# Lista original:  [10, 85, 74, 6, 5, 15, 122, 35, 98, 48, 564, 165, 154]
# Números pares:  [10, 74, 6, 122, 98, 48, 564, 154]
