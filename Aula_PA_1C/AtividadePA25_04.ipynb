# %%
#1. Comparação de Idades

##entrada
idade1=int(input("digite a idade 1: "))
idade2=int(input("digite a idade 2: "))

##processamento
idade1=(idade1 > idade2)
print(idade1)

idade2=(idade2 < idade1)
print(idade2)

##saida
print("a idade 1 é maior que a idade 2?", idade1)
# Out:
# digite a idade 1: 25
# digite a idade 2: 24
# True
# False
# a idade 1 é maior que a idade 2? True

# %%
#2. Validação de Acesso

##entrada
idade=int(input("digite sua idade"))
senha=int(input("digite a senha"))

##processamento
pode = idade>=18 and senha==1234


##saída
print("pode acessar sistema ?", pode)
# Out:
# digite sua idade17
# digite a senha1234
# pode acessar sistema ? False

# %%
#3. Número Fora de Intervalo

##entrada
numero=int(input("digite o número"))

##processamento
esta=numero<10 or numero>50

##saída
print("o numero nao está entre 10 e 50 ?", esta)
# Out:
# digite o número19
# o numero nao está entre 10 e 50 ? False

# %%
#4. Compra Aprovação

##entrada
preço=float(input("digite o preço "))
saldo=float(input("digite o saldo "))
digite=int(input("digite o cupom "))

##processamento
pode= preço<=saldo
print(pode)
cupom=digite==1234 and preço>=saldo
print(cupom)


##saida
print("pode comprar o produto com o saldo ?", pode)
print("pode comprar o produto com o cupom ?", cupom)
# Out:
# digite o preço 199
# digite o saldo 150
# digite o cupom 20
# False
# False
# pode comprar o produto com o saldo ? False
# pode comprar o produto com o cupom ? False

# %%
#5. Checar Condições Múltiplas


##entrada
numero=int(input(" digite o numero"))

##processamento
par=numero%2==0
print(par)

positivo=numero>0
print(positivo)

##saida
print("o numero é par ?", par)
print("o numero é positivo ?" , positivo)
# Out:
#  digite o numero11
# False
# True
# o numero é par ? False
# o numero é positivo ? True

# %%
#6. Verificar se é Adolescente

##entrada
idade=int(input("digite a idade"))

##processamento
esta=idade>=13 and idade<=17

##saida
print("a pessoa tem entre 13 a 17 anos ?", esta)
# Out:
# digite a idade15
# a pessoa tem entre 13 a 17 anos ? True

# %%
#7. Senha Correta ou Admin

##entrada
adm=int(input('digite 1 se voce é adm ? ' ))
senha=int(input('digite a senha ' ))

##processamento
adm==1
senha = senha==1234

##saida
print("pode acessar o sistema ?", senha)
# Out:
# digite 1 se voce é adm ? 2
# digite a senha 1235
# pode acessar o sistema ? False

# %%
#8. Nota Para Aprovação

##entrada
nota=float(input("digite a nota "))
presente=int(input("digite 1 se esta presente "))

##processamento
aprovado=nota>=6
presente==1

##saida
print("o aluno foi aprovado ?", aprovado)
# Out:
# digite a nota 8
# digite 1 se esta presente 1
# o aluno foi aprovado ? True

# %%
#9. Sistema de Multa de Velocidade

##entrada
velocidade=float(input("digite a sua velocidade "))

##processamento
limite=80
multa=velocidade>limite

##saida
print("voce foi multado ?", multa)
# Out:
# digite a sua velocidade 89
# voce foi multado ? True

# %%
#10. Triagem de Evento

##entrada
convite=int(input("digite 10 se voce tem o convite "))
idade=int(input("digite a sua idade "))

##processamento
convite==10
idade= idade>=18

#saida
print("pode entrar no evento ?", idade)
# Out:
# digite 10 se voce tem o convite 9
# digite a sua idade 12
# pode entrar no evento ? False
